# %% [markdown]
# # Enter Name of Classification Model here

# %% [markdown]
# ## Importing libraries

# %% [markdown]
# ## Importing dataset

# %% [markdown]
# ## Splitting the dataset into Training & Test set

# %% [markdown]
# ## Feature Scaling

# %% [markdown]
# ## SVM Training on Training set

# %% [markdown]
# ## Confusion Matrix
