# %%
import numpy as np

# %%
demo = [10,20,30]
np.array(demo)
# Out:
# array([10, 20, 30])

# %%
#demo2 = [10,20,"30"]
#np.array(demo2)

demo2 = [10,20,"xyz"]
np.array(demo2)
# Out:
# array(['10', '20', 'xyz'], dtype='<U21')

# %%
np.zeros(5, int)
x1 = np.ones(5)

print(x1)
# Out:
# [1. 1. 1. 1. 1.]

# %%
x1[2] = "xyz"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-4c5efb598ed6> in <module>()
# ----> 1 x1[2] = "xyz"
#
# ValueError: could not convert string to float: 'xyz'

# %%
x = np.zeros(10)
x.dtype
# Out:
# dtype('float64')

# %%
y = np.zeros(10, int)
y.dtype
# Out:
# dtype('int64')
