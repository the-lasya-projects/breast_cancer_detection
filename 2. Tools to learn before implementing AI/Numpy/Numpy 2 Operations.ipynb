# %%
import numpy as np
import math as m

# %%
x = [1,2,3]
y = [3,5,6]

x = x +
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-587b9d1a4ed4> in <module>()
#       2 y = [3,5,6]
#       3
# ----> 4 x = x + 10
#
# TypeError: can only concatenate list (not "int") to list

# %%
x = np.array([1,2,3])
y = np.array([3,5,6])
x = x + 10
print(x)

print(x+y)
# Out:
# [11 12 13]
# [14 17 19]

# %%
z = np.array([100,200,300,400])

print(y + z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-21f84efaf468> in <module>()
#       1 z = np.array([100,200,300,400])
#       2
# ----> 3 print(y + z)
#
# ValueError: operands could not be broadcast together with shapes (3,) (4,)

# %%
print(x*2)
print(x*y)
print(x**3)
# Out:
# [22 24 26]
# [33 60 78]
# [1331 1728 2197]

# %%
print(x.mean())
print(x.sum())
# Out:
# 12.0
# 36

# %%
p1 = np.array([2,2,2])
p2 = np.array([1,1,1])

val = ((p1-p2)**2).sum()
print(val)

#val2 = val.sum()
#print(val2)

m.sqrt(val)
# Out:
# 3
# 1.7320508075688772

# %%
pts = np.array([4,5,6,7])

value1 = ((pts - pts.mean())**2).sum()
print(value1)
m.sqrt(value1)
# Out:
# 5.0
# 2.23606797749979

# %%
m1 = np.array([1,2,3])
m2 = np.array([4,5,6])

print(m1.dot(m2))
# Out:
# 32
# 32
