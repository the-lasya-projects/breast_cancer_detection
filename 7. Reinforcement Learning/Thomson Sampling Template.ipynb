# %% [markdown]
# # Thomson Sampling

# %% [markdown]
# ## Importing libraries

# %% [markdown]
# ## Importing dataset

# %% [markdown]
# ## Implementation

# %% [markdown]
# ## Histogram Visualization
