# %% [markdown]
# # Upper Confidence Bound

# %% [markdown]
# ## Importing libraries

# %% [markdown]
# ## Importing dataset

# %% [markdown]
# ## Implementation

# %% [markdown]
# ## Histogram Visualization
