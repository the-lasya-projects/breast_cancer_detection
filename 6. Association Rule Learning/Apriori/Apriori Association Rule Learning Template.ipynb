# %% [markdown]
# # Apriori

# %% [markdown]
# ## Importing libraries

# %% [markdown]
# ## Importing dataset

# %% [markdown]
# ## Apriori Training on Dataset

# %% [markdown]
# ## Visualizing

# %% [markdown]
# ### Raw Results

# %% [markdown]
# ### Proper Display
